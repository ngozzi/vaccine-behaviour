# %%
# libraries
import pandas as pd
url = "https://health-infobase.canada.ca/src/data/covidLive/vaccination-coverage-byAgeAndSex.csv"
#https://health-infobase.canada.ca/covid-19/vaccination-coverage/

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    pruid prename prfname    week_end sex    age numtotal_atleast1dose  \
# 0      1  Canada  Canada  2020-12-19   f   0-15                     0
# 1      1  Canada  Canada  2020-12-19   f  16-69                  5875
# 2      1  Canada  Canada  2020-12-19   f  70-74                    62
# 3      1  Canada  Canada  2020-12-19   f  75-79                    42
# 4      1  Canada  Canada  2020-12-19   f    80+                   241
#
#   numtotal_1dose  numtotal_1doserange numtotal_2doses  numtotal_2dosesrange  \
# 0              0                  NaN               0                   NaN
# 1           5875                  NaN               0                   NaN
# 2             62                  NaN               0                   NaN
# 3             42                  NaN               0                   NaN
# 4            241                  NaN               0                   NaN
#
#   prop_atleast1dose   prop_1dose prop_1doserange prop_2doses  \
# 0                 0            0             NaN           0
# 1       0.133783026  0.133783026             NaN           0
# 2        0.01888275   0.01888275             NaN           0
# 3       0.017892441  0.017892441             NaN           0
# 4       0.068250493  0.068250493             NaN           0
#
#    prop_2dosesrange  numweekdelta_atleast1dose  numweekdelta_2doses  \
# 0               NaN                        NaN                  NaN
# 1               NaN                        NaN                  NaN
# 2               NaN                        NaN                  NaN
# 3               NaN                        NaN                  NaN
# 4               NaN                        NaN                  NaN
#
#    propweekdelta_1dose  propweekdelta_2doses
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
